# %%
import numpy as np 
import pandas as pd

np.random.seed(42)

#have 2 groups for purchases
control_sales = np.random.normal(loc=45, scale=15, size=500)
test_sales = np.random.normal(loc=52, scale=18, size=500)

df_control = pd.DataFrame({'group':'control','purchase_amount':control_sales})
df_test = pd.DataFrame({'control':'test', 'purchase_amount': test_sales})
df=pd.concat([df_control,df_test],ignore_index=True)

print(df.head(20))
# Out:
#       group  purchase_amount control
# 0   control        52.450712     NaN
# 1   control        42.926035     NaN
# 2   control        54.715328     NaN
# 3   control        67.845448     NaN
# 4   control        41.487699     NaN
# 5   control        41.487946     NaN
# 6   control        68.688192     NaN
# 7   control        56.511521     NaN
# 8   control        37.957884     NaN
# 9   control        53.138401     NaN
# 10  control        38.048735     NaN
# 11  control        38.014054     NaN
# 12  control        48.629434     NaN
# 13  control        16.300796     NaN
# 14  control        19.126233     NaN
# 15  control        36.565687     NaN
# 16  control        29.807533     NaN
# 17  control        49.713710     NaN
# 18  control        31.379639     NaN
# 19  control        23.815444     NaN
